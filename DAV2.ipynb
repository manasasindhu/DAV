# %%
import pandas as pd
df=pd.read_csv("StudentsPerformance.csv")
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score   age
# 0                      none          72             72             74  56.0
# 1                 completed          69             90             88  67.0
# 2                      none          90             95             93  88.0
# 3                      none          47             57             44  93.0
# 4                      none          76             78             75  44.0
# ..                      ...         ...            ...            ...   ...
# 995               completed          88             99             95   NaN
# 996                    none          62             55             55   NaN
# 997               completed          59             71             65   NaN
# 998               completed          68             78             77   NaN
# 999                    none          77             86             86   NaN
#
# [1000 rows x 9 columns]

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score   age
# 0                    none          72             72             74  56.0
# 1               completed          69             90             88  67.0
# 2                    none          90             95             93  88.0
# 3                    none          47             57             44  93.0
# 4                    none          76             78             75  44.0

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  age
# 995               completed          88             99             95  NaN
# 996                    none          62             55             55  NaN
# 997               completed          59             71             65  NaN
# 998               completed          68             78             77  NaN
# 999                    none          77             86             86  NaN

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'age'],
#       dtype='str')

# %%
df.dtypes
# Out:
# gender                             str
# race/ethnicity                     str
# parental level of education        str
# lunch                              str
# test preparation course            str
# math score                       int64
# reading score                    int64
# writing score                    int64
# age                            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   str
#  1   race/ethnicity               1000 non-null   str
#  2   parental level of education  1000 non-null   str
#  3   lunch                        1000 non-null   str
#  4   test preparation course      1000 non-null   str
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   age                          98 non-null     float64
# dtypes: float64(1), int64(3), str(5)
# memory usage: 50.9 KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score        age
# count  1000.00000    1000.000000    1000.000000  98.000000
# mean     66.08900      69.169000      68.054000  66.642857
# std      15.16308      14.600192      15.195657  13.372730
# min       0.00000      17.000000      10.000000  28.000000
# 25%      57.00000      59.000000      57.750000  57.000000
# 50%      66.00000      70.000000      69.000000  66.000000
# 75%      77.00000      79.000000      79.000000  76.000000
# max     100.00000     100.000000     100.000000  93.000000

# %%
df["age"].mean()
# Out:
# np.float64(66.64285714285714)

# %%
df["age"].median()
# Out:
# np.float64(66.0)

# %%
df["age"].mode()
# Out:
# 0    65.0
# Name: age, dtype: float64

# %%
df["age"].var()
# Out:
# np.float64(178.8298969072165)

# %%
df["age"].std()
# Out:
# np.float64(13.37272959822401)

# %%
df["age"].min()
# Out:
# np.float64(28.0)

# %%
df["age"].max()
# Out:
# np.float64(93.0)

# %%
df["age"].count()
# Out:
# np.int64(98)

# %%
df["race/ethnicity"].unique()
# Out:
# <StringArray>
# ['group B', 'group C', 'group A', 'group D', 'group E']
# Length: 5, dtype: str

# %%
df["race/ethnicity"].nunique()
# Out:
# 5

# %%
df["race/ethnicity"].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score    age
# 0                      False       False          False          False  False
# 1                      False       False          False          False  False
# 2                      False       False          False          False  False
# 3                      False       False          False          False  False
# 4                      False       False          False          False  False
# ..                       ...         ...            ...            ...    ...
# 995                    False       False          False          False   True
# 996                    False       False          False          False   True
# 997                    False       False          False          False   True
# 998                    False       False          False          False   True
# 999                    False       False          False          False   True
#
# [1000 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# gender                           0
# race/ethnicity                   0
# parental level of education      0
# lunch                            0
# test preparation course          0
# math score                       0
# reading score                    0
# writing score                    0
# age                            902
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# gender                          0.0
# race/ethnicity                  0.0
# parental level of education     0.0
# lunch                           0.0
# test preparation course         0.0
# math score                      0.0
# reading score                   0.0
# writing score                   0.0
# age                            90.2
# dtype: float64

# %%
df.dropna()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# ..     ...            ...                         ...           ...
# 93    male        group C          associate's degree  free/reduced
# 94  female        group B                some college      standard
# 95    male        group C          associate's degree  free/reduced
# 96    male        group B            some high school      standard
# 97  female        group E                some college      standard
#
#    test preparation course  math score  reading score  writing score   age
# 0                     none          72             72             74  56.0
# 1                completed          69             90             88  67.0
# 2                     none          90             95             93  88.0
# 3                     none          47             57             44  93.0
# 4                     none          76             78             75  44.0
# ..                     ...         ...            ...            ...   ...
# 93               completed          43             45             50  57.0
# 94                    none          79             86             92  62.0
# 95               completed          78             81             82  76.0
# 96               completed          65             66             62  76.0
# 97               completed          63             72             70  82.0
#
# [98 rows x 9 columns]

# %%
df.fillna(0)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score   age
# 0                      none          72             72             74  56.0
# 1                 completed          69             90             88  67.0
# 2                      none          90             95             93  88.0
# 3                      none          47             57             44  93.0
# 4                      none          76             78             75  44.0
# ..                      ...         ...            ...            ...   ...
# 995               completed          88             99             95   0.0
# 996                    none          62             55             55   0.0
# 997               completed          59             71             65   0.0
# 998               completed          68             78             77   0.0
# 999                    none          77             86             86   0.0
#
# [1000 rows x 9 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score   age
# 0                      none          72             72             74  56.0
# 1                 completed          69             90             88  67.0
# 2                      none          90             95             93  88.0
# 3                      none          47             57             44  93.0
# 4                      none          76             78             75  44.0
# ..                      ...         ...            ...            ...   ...
# 995               completed          88             99             95   NaN
# 996                    none          62             55             55   NaN
# 997               completed          59             71             65   NaN
# 998               completed          68             78             77   NaN
# 999                    none          77             86             86   NaN
#
# [1000 rows x 9 columns]

# %%
df["age"]
# Out:
# 0      56.0
# 1      67.0
# 2      88.0
# 3      93.0
# 4      44.0
#        ...
# 995     NaN
# 996     NaN
# 997     NaN
# 998     NaN
# 999     NaN
# Name: age, Length: 1000, dtype: float64

# %%
df[["age","gender"]]
# Out:
#       age  gender
# 0    56.0  female
# 1    67.0  female
# 2    88.0  female
# 3    93.0    male
# 4    44.0    male
# ..    ...     ...
# 995   NaN  female
# 996   NaN    male
# 997   NaN  female
# 998   NaN  female
# 999   NaN  female
#
# [1000 rows x 2 columns]

# %%
df.iloc[0:5]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score   age
# 0                    none          72             72             74  56.0
# 1               completed          69             90             88  67.0
# 2                    none          90             95             93  88.0
# 3                    none          47             57             44  93.0
# 4                    none          76             78             75  44.0

# %%
df[df["age"]>30]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# ..     ...            ...                         ...           ...
# 93    male        group C          associate's degree  free/reduced
# 94  female        group B                some college      standard
# 95    male        group C          associate's degree  free/reduced
# 96    male        group B            some high school      standard
# 97  female        group E                some college      standard
#
#    test preparation course  math score  reading score  writing score   age
# 0                     none          72             72             74  56.0
# 1                completed          69             90             88  67.0
# 2                     none          90             95             93  88.0
# 3                     none          47             57             44  93.0
# 4                     none          76             78             75  44.0
# ..                     ...         ...            ...            ...   ...
# 93               completed          43             45             50  57.0
# 94                    none          79             86             92  62.0
# 95               completed          78             81             82  76.0
# 96               completed          65             66             62  76.0
# 97               completed          63             72             70  82.0
#
# [97 rows x 9 columns]

# %%
df.rename(columns={"age":"age_years"})
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      age_years
# 0         56.0
# 1         67.0
# 2         88.0
# 3         93.0
# 4         44.0
# ..         ...
# 995        NaN
# 996        NaN
# 997        NaN
# 998        NaN
# 999        NaN
#
# [1000 rows x 9 columns]

# %%
df.drop("age",axis=1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72            7.2             74
# 1                 completed          69            6.9             88
# 2                      none          90            9.0             93
# 3                      none          47            4.7             44
# 4                      none          76            7.6             75
# ..                      ...         ...            ...            ...
# 995               completed          88            8.8             95
# 996                    none          62            6.2             55
# 997               completed          59            5.9             65
# 998               completed          68            6.8             77
# 999                    none          77            7.7             86
#
# [1000 rows x 8 columns]

# %%
pd.concat([df,df])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score   age
# 0                      none          72            7.2             74  56.0
# 1                 completed          69            6.9             88  67.0
# 2                      none          90            9.0             93  88.0
# 3                      none          47            4.7             44  93.0
# 4                      none          76            7.6             75  44.0
# ..                      ...         ...            ...            ...   ...
# 995               completed          88            8.8             95   NaN
# 996                    none          62            6.2             55   NaN
# 997               completed          59            5.9             65   NaN
# 998               completed          68            6.8             77   NaN
# 999                    none          77            7.7             86   NaN
#
# [2000 rows x 9 columns]
